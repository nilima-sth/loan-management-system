# %%
import pandas as pd

# %%
df_data=pd.read_csv('../data/lms_advanced_master.csv')
df_data.head()
# Out:
#    applicant_age  gender       province  monthly_income_npr  loan_amount_npr  \
# 0             42  Female  Sudurpashchim               35300           255000
# 1             27    Male        Madhesh               17800           173000
# 2             34    Male        Karnali               23300           193000
# 3             40    Male        Lumbini               50700           477000
# 4             43    Male        Bagmati               73100          1292000
#
#    loan_tenure_months  max_dpd_24m  overdue_count_12m  bounce_count_12m  \
# 0                  48            0                  0                 0
# 1                  84            0                  0                 0
# 2                 120            0                  0                 0
# 3                 120           10                  4                 2
# 4                 120            0                  0                 0
#
#    restructure_count  ...  credit_history_months  hard_enquiry_6m  \
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   applicant_age           8000 non-null   int64
#  1   gender                  8000 non-null   object
#  2   province                8000 non-null   object
#  3   monthly_income_npr      8000 non-null   int64
#  4   loan_amount_npr         8000 non-null   int64
#  5   loan_tenure_months      8000 non-null   int64
#  6   max_dpd_24m             8000 non-null   int64
#  7   overdue_count_12m       8000 non-null   int64
#  8   bounce_count_12m        8000 non-null   int64
#  9   restructure_count       8000 non-null   int64
#  10  dscr                    8000 non-null   float64
#  11  emi_income_ratio        8000 non-null   float64
#  12  income_stability        8000 non-null   float64
#  13  avg_bank_balance_6m     8000 non-null   float64
# ...

# %%
df_data.isnull().sum()
# Out:
# applicant_age             0
# gender                    0
# province                  0
# monthly_income_npr        0
# loan_amount_npr           0
# loan_tenure_months        0
# max_dpd_24m               0
# overdue_count_12m         0
# bounce_count_12m          0
# restructure_count         0
# dscr                      0
# emi_income_ratio          0
# income_stability          0
# avg_bank_balance_6m       0
# income_cagr_2y            0
# ltv_ratio                 0
# collateral_score          0
# insurance_flag            0
# active_loan_count         0
# credit_history_months     0
# hard_enquiry_6m           0
# bank_tenure_months        0
# product_count             0
# avg_deposit_12m           0
# bs_month_applied          0
# festival_proximity        0
# district_npa_rate         0
# remittance_inflow_flag    0
# defaulted                 0
# dtype: int64

# %%
# Checking for any missing features
required_features = [
    "max_dpd_24m",
    "overdue_count_12m",
    "bounce_count_12m",
    "restructure_count",
    "dscr",
    "emi_income_ratio",
    "income_stability",
    "avg_bank_balance_6m",
    "income_cagr_2y",
    "ltv_ratio",
    "collateral_score",
    "insurance_flag",
    "active_loan_count",
    "credit_history_months",
    "hard_enquiry_6m",
    "bank_tenure_months",
    "product_count",
    "avg_deposit_12m",
    "bs_month_applied",
    "festival_proximity",
    "district_npa_rate",
    "remittance_inflow_flag"
]

missing_features = [f for f in required_features if f not in df_data.columns]

print("Missing features:", missing_features)
# Out:
# Missing features: []
